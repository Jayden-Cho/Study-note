# %% [markdown]
# Pandas를 이용해 Naver금융에서 주식데이터를 가져오기.

# %% [markdown]
# # 한국거래소(krx)에서 종목코드 가져오기
#
# 원하는 종목의 주식데이터를 가져오기 위해 코스피(KOSPI)와 코스닥(KOSDAQ)의 종목코드가 필요하다.
# - `pandas`모듈의 `pandas.read_html()`을 이용해 종목코드를 가져올 수 있다.
#     - `pandas.read_html()`은 HTML에서 `<table></table>` 태그를 찾아 자동으로 `DataFrame`형식으로 만들어준다.

# %%
import pandas as pd

code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13')
code_df
# Out:
# [           회사명    종목코드                     업종  \
#  0          DSR  155660            1차 비철금속 제조업
#  1        GS글로벌    1250              상품 종합 도매업
#  2        HSD엔진   82740          일반 목적용 기계 제조업
#  3        LG이노텍   11070               전자부품 제조업
#  4          OCI   10060            기초 화학물질 제조업
#  ...        ...     ...                    ...
#  2339     원바이오젠  278380  의료용품 및 기타 의약 관련제품 제조업
#  2340   지앤이헬스케어  299480            기타 섬유제품 제조업
#  2341        틸론  217880         소프트웨어 개발 및 공급업
#  2342     판도라티비  202960         소프트웨어 개발 및 공급업
#  2343  한국미라클피플사  331660            기타 화학제품 제조업
#
#                                                     주요제품         상장일  결산월  \
#  0                                                합섬섬유로프  2013-05-15  12월
#  1     수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
#  2                                        대형선박용엔진,내연발전엔진  2011-01-04  12월
#  3                                           기타 전자부품 제조업  2008-07-24  12월
#  4      타르제품,카본블랙,무수프탈산,농약원제,석탄화학제품,정밀화학제품,플라스틱창호재 제조,판매  1985-07-09  12월
#  ...                                                 ...         ...  ...
#  2339                                        의료기기(창상피복재)  2019-06-03  12월
#  2340                                               면생리대  2018-06-29  12월
#  2341                    Cloud Solution (D,A,E,Rstation)  2015-05-28  12월
#  2342                                     판도라TV, KM 플레이어  2014-08-11  12월
#  2343                                     은나노스텝, 닥터오렌지 등  2019-10-28  12월
#
#                              대표자명                         홈페이지     지역
#  0                            홍석빈           http://www.dsr.com  부산광역시
#  1                            김태형       http://www.gsgcorp.com  서울특별시
#  2                            고영열  http://www.doosanengine.com   경상남도
#  3                            정철동   http://www.lginnotek.co.kr  서울특별시
#  4     백우석, 이우현, 김택중(3인, 각자 대표이사)         http://www.oci.co.kr  서울특별시
#  ...                          ...                          ...    ...
#  2339                         김원일   http://www.wonbiogen.co.kr   경상북도
#  2340                         장영민     http://www.hannahpad.com    경기도
#  2341                    최백준, 최용호       http://www.tilon.co.kr  서울특별시
#  2342                         김경익        http://www.pandora.tv    경기도
#  2343                         이호경        http://www.kmpc.co.kr    경기도
#
#  [2344 rows x 9 columns]]

# %% [markdown]
# 알아보기 어려운 데이터들로 가득하다.
# - 먼저 데이터 타입이 무엇인지, 길이가 몇인지 알아보자.

# %%
print('type :',type(code_df),', length :',len(code_df))
# Out:
# type : <class 'list'> , length : 1

# %% [markdown]
# 그래도 적어도 데이터 자체가 리스트 안에 있다는 것을 알 수 있다.
# - 데이터 타입이 리스트이므로 인덱싱이 가능하다. 첫번째(이자 물론 마지막) 요소를 인덱싱하자.
# - 인덱싱에 추가로 첫 번째 열을 `header`로 설정하자. `header=0`으로 설정하면 된다.

# %%
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
code_df.head()
# Out:
#      회사명    종목코드             업종  \
# 0    DSR  155660    1차 비철금속 제조업
# 1  GS글로벌    1250      상품 종합 도매업
# 2  HSD엔진   82740  일반 목적용 기계 제조업
# 3  LG이노텍   11070       전자부품 제조업
# 4    OCI   10060    기초 화학물질 제조업
#
#                                                 주요제품         상장일  결산월  \
# 0                                             합섬섬유로프  2013-05-15  12월
# 1  수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 2                                     대형선박용엔진,내연발전엔진  2011-01-04  12월
# 3                                        기타 전자부품 제조업  2008-07-24  12월
# 4   타르제품,카본블랙,무수프탈산,농약원제,석탄화학제품,정밀화학제품,플라스틱창호재 제조,판매  1985-07-09  12월
#
#                          대표자명                         홈페이지     지역
# 0                         홍석빈           http://www.dsr.com  부산광역시
# 1                         김태형       http://www.gsgcorp.com  서울특별시
# 2                         고영열  http://www.doosanengine.com   경상남도
# 3                         정철동   http://www.lginnotek.co.kr  서울특별시
# 4  백우석, 이우현, 김택중(3인, 각자 대표이사)         http://www.oci.co.kr  서울특별시

# %% [markdown]
# 데이터프레임을 성공적으로 출력했으니 이제 입맛에 맞게 수정하자.

# %%
code_df.종목코드
# Out:
# 0       155660
# 1         1250
# 2        82740
# 3        11070
# 4        10060
#          ...
# 2339    278380
# 2340    299480
# 2341    217880
# 2342    202960
# 2343    331660
# Name: 종목코드, Length: 2344, dtype: int64

# %% [markdown]
# 종목코드열을 보면 4자리부터 6자리까지 다양하다. 일괄적으로 6자리로 맞추자.
# - `map()` 함수를 사용하면 일괄적인 처리가 가능하다. `map()` 함수 안에 문자열 포맷팅으로 자릿수를 지정하자.
# - 종목코드는 Series 타입이므로 map() 함수 사용이 가능하다.

# %%
# {인덱스:0개수d'}'.format(숫자)
code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)
code_df.head()
# Out:
#      회사명    종목코드             업종  \
# 0    DSR  155660    1차 비철금속 제조업
# 1  GS글로벌  001250      상품 종합 도매업
# 2  HSD엔진  082740  일반 목적용 기계 제조업
# 3  LG이노텍  011070       전자부품 제조업
# 4    OCI  010060    기초 화학물질 제조업
#
#                                                 주요제품         상장일  결산월  \
# 0                                             합섬섬유로프  2013-05-15  12월
# 1  수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 2                                     대형선박용엔진,내연발전엔진  2011-01-04  12월
# 3                                        기타 전자부품 제조업  2008-07-24  12월
# 4   타르제품,카본블랙,무수프탈산,농약원제,석탄화학제품,정밀화학제품,플라스틱창호재 제조,판매  1985-07-09  12월
#
#                          대표자명                         홈페이지     지역
# 0                         홍석빈           http://www.dsr.com  부산광역시
# 1                         김태형       http://www.gsgcorp.com  서울특별시
# 2                         고영열  http://www.doosanengine.com   경상남도
# 3                         정철동   http://www.lginnotek.co.kr  서울특별시
# 4  백우석, 이우현, 김택중(3인, 각자 대표이사)         http://www.oci.co.kr  서울특별시

# %% [markdown]
# 다음은 불필요한 열을 제거하자.
# - 지금 필요한 것은 회사명과 종목코드. 나머지 열들은 제외하자.

# %%
code_df = code_df[['회사명', '종목코드']]
code_df.head()
# Out:
#      회사명    종목코드
# 0    DSR  155660
# 1  GS글로벌  001250
# 2  HSD엔진  082740
# 3  LG이노텍  011070
# 4    OCI  010060

# %% [markdown]
# 이제 한글로된 컬럼명을 영어로 바꿔준다.

# %%
code_df = code_df.rename(columns={'회사명' : 'name', '종목코드' : 'code'})
code_df.head()
# Out:
#     name    code
# 0    DSR  155660
# 1  GS글로벌  001250
# 2  HSD엔진  082740
# 3  LG이노텍  011070
# 4    OCI  010060

# %% [markdown]
# # Naver금융에서 종목 별 일자 데이터 가져오기
#
# 예시로 신라젠(215600)의 일자 데이터를 가져와보자.
# - 신라젠의 데이터 말고도 사용자가 원하는 임의의 데이터도 가져올 수 있도록 `get_url` 함수를 만들자.
# - BeautifulSoup이나 Scrapy를 사용해 크롤링할 수도 있지만 이번엔 간단하게 20페이지만 가져온다.

# %% [markdown]
# url을 보면 종목코드에 따라 맨 뒤 url이 달라진다. 신라젠(215600)은 뒤에 해당 종목코드가 붙어있다.
# - 데이터프레임에서 종목코드를 가져와 url 뒤에 붙여넣으면 해당 종목의 url을 불러올 수 있다.

# %% [markdown]
# `query()` 메소드를 사용하면 데이터프레임에 질문을 던질 수 있다. 일단 신라젠에 해당하는 행을 출력해보자.
# - `format()` 을 사용하면 좀 더 정교한 문자열 대입이 가능하다.

# %%
code_df.query("name=='{}'".format('신라젠'))
# Out:
#     name    code
# 469  신라젠  215600

# %% [markdown]
# 신라젠의 행을 출력했으니 신라젠의 'code'를 출력하자.

# %%
code = code_df.query("name=='{}'".format('신라젠'))['code']
code
# Out:
# 469    215600
# Name: code, dtype: object

# %% [markdown]
# 보면 자료형이 Series로 나온다. 문자열에 대입할 수 있게 string으로 변환한다.
# - Series 형은 `to_string()` 함수를 사용해 간단하게 변환할 수 있다.

# %%
code_df.query("name=='{}'".format('신라젠'))['code'].to_string()
# Out:
# '469    215600'

# %% [markdown]
# 인덱스를 제외하기 위해 index parameter를 False 처리해준다.

# %%
code_df.query("name=='{}'".format('신라젠'))['code'].to_string(index=False)
# Out:
# ' 215600'

# %% [markdown]
# 종목코드 앞에 blank space가 존재한다. `lstrip()` 함수를 사용해 왼쪽 빈칸을 지워주자.

# %%
code_df.query("name=='{}'".format('신라젠'))['code'].to_string(index=False).lstrip()
# Out:
# '215600'

# %% [markdown]
# 종목코드 얻는 법도 알았으니 `get_url()` 함수를 만들자.

# %%
def get_url(item_name, code_df):
    code = (code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False)).lstrip()
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    
    print("요청 URL = {}".format(url))
    return url

item_name = '신라젠'
get_url(item_name, code_df)
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=215600
# 'http://finance.naver.com/item/sise_day.nhn?code=215600'

# %% [markdown]
# 성공적으로 url이 출력된다. 이제 페이지 별로 데이터를 가져올 차례.
# - 빈 데이터프레임을 만들고 그곳에 1페이지부터 20페이지의 데이터를 입력한다.
# - for loop와 이전에 사용했던 `format()`을 사용하면 간단하게 처리 가능하다.

# %%
'''df = pd.DataFrame()

url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)

for page in range(1, 21):
    pg_url = '{url}&page={page}'.format(url=url, page=page)
    df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
'''
# Out:
# "df = pd.DataFrame()\n\nurl = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)\n\nfor page in range(1, 21):\n    pg_url = '{url}&page={page}'.format(url=url, page=page)\n    df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)\n"

# %% [markdown]
# 299번째 행을 보면 NaN 값들이 있다. 제외하자.

# %%
'''df = df.dropna()
df.head()'''
# Out:
# 'df = df.dropna()\ndf.head()'

# %% [markdown]
# **전체 코드**

# %%
def get_url(item_name, code_df):
    code = (code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False)).lstrip()
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    
    print("요청 URL = {}".format(url))
    return url

item_name = '신라젠'
url = get_url(item_name, code_df)

df = pd.DataFrame()

for page in range(1, 21):
    pg_url = '{url}&page={page}'.format(url=url, page=page)
    df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
    
df = df.dropna()

df.head()
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=215600
#            날짜       종가    전일비       시가       고가       저가        거래량
# 1  2019.12.11  13850.0  500.0  14250.0  14350.0  13800.0  1062162.0
# 2  2019.12.10  14350.0  300.0  14300.0  14500.0  14100.0  1542255.0
# 3  2019.12.09  14050.0  300.0  13850.0  14200.0  13500.0  1594531.0
# 4  2019.12.06  13750.0  550.0  13300.0  13950.0  13300.0  1965387.0
# 5  2019.12.05  13200.0  550.0  13800.0  13850.0  13000.0  1864402.0

# %% [markdown]
# 데이터프레임을 수정해보자. 먼저 종가, 전일비, 시가, 고가, 저가, 거래량을 int로 형변환시켜준다.

# %%
# df[['종가', '전일비', '시가', '고가', '저가', '거래량']].astype(int)만 적으면 일회성으로 변환만 되기 때문에 저장을 해준다.
df[['종가', '전일비', '시가', '고가', '저가', '거래량']]\
    = df[['종가', '전일비', '시가', '고가', '저가', '거래량']].astype(int)
df.head()
# Out:
#            날짜     종가  전일비     시가     고가     저가      거래량
# 1  2019.12.11  13850  500  14250  14350  13800  1062162
# 2  2019.12.10  14350  300  14300  14500  14100  1542255
# 3  2019.12.09  14050  300  13850  14200  13500  1594531
# 4  2019.12.06  13750  550  13300  13950  13300  1965387
# 5  2019.12.05  13200  550  13800  13850  13000  1864402

# %% [markdown]
# 정렬할수 있도록 날짜 열을 date로 형변환한다.

# %%
df['날짜'] = pd.to_datetime(df['날짜'])
df.head()
# Out:
#           날짜     종가  전일비     시가     고가     저가      거래량
# 1 2019-12-11  13850  500  14250  14350  13800  1062162
# 2 2019-12-10  14350  300  14300  14500  14100  1542255
# 3 2019-12-09  14050  300  13850  14200  13500  1594531
# 4 2019-12-06  13750  550  13300  13950  13300  1965387
# 5 2019-12-05  13200  550  13800  13850  13000  1864402

# %% [markdown]
# 마지막으로 날짜를 오름차순으로 정리한다.

# %%
df = df.sort_values(by=['날짜'], ascending=True)
df.head()
# Out:
#             날짜     종가   전일비     시가     고가     저가      거래량
# 298 2019-02-22  72000  1400  72900  73500  71800   842080
# 297 2019-02-25  73300  1300  72100  73900  71500   799032
# 296 2019-02-26  72800   500  73600  74400  72800   659441
# 295 2019-02-27  73500   700  72700  73800  72300   555903
# 294 2019-02-28  74300   800  74200  76000  71300  2467512

# %% [markdown]
# # Plotly를 이용해 Time Series 그래프 그리기

# %% [markdown]
# 먼저 필요한 모듈 import하고 시작.

# %%
import plotly.offline as offline
import plotly.graph_objs as go

trace = go.Scatter(x=df.날짜,
                   y=df.전일비,
                   name=item_name)

data=[trace]

fig = go.Figure(data=data)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="b59215c5-0fd5-4f6c-b88a-ed1ecfdab612" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b59215c5-0fd5-4f6c-b88a-ed1ecfdab612")) {
#                     Plotly.newPlot(
#                         'b59215c5-0fd5-4f6c-b88a-ed1ecfdab612',
#                         [{"name": "\uc2e0\ub77c\uc820", "type": "scatter", "x": ["2019-02-22T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23T00:00:00", "2019-05-24T00:00:00", "2019-05-27T00:00:00", "2019-05-28T00:00:00", "2019-05-29T00:00:00", "2019-05-30T00:00:00", "2019-05-31T00:00:00", "2019-06-03T00:00:00", "2019-06-04T00:00:00", "2019-06-05T00:00:00", "2019-06-07T00:00:00", "2019-06-10T00:00:00", "2019-06-11T00:00:00", "2019-06-12T00:00:00", "2019-06-13T00:00:00", "2019-06-14T00:00:00", "2019-06-17T00:00:00", "2019-06-18T00:00:00", "2019-06-19T00:00:00", "2019-06-20T00:00:00", "2019-06-21T00:00:00", "2019-06-24T00:00:00", "2019-06-25T00:00:00", "2019-06-26T00:00:00", "2019-06-27T00:00:00", "2019-06-28T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00", "2019-07-05T00:00:00", "2019-07-08T00:00:00", "2019-07-09T00:00:00", "2019-07-10T00:00:00", "2019-07-11T00:00:00", "2019-07-12T00:00:00", "2019-07-15T00:00:00", "2019-07-16T00:00:00", "2019-07-17T00:00:00", "2019-07-18T00:00:00", "2019-07-19T00:00:00", "2019-07-22T00:00:00", "2019-07-23T00:00:00", "2019-07-24T00:00:00", "2019-07-25T00:00:00", "2019-07-26T00:00:00", "2019-07-29T00:00:00", "2019-07-30T00:00:00", "2019-07-31T00:00:00", "2019-08-01T00:00:00", "2019-08-02T00:00:00", "2019-08-05T00:00:00", "2019-08-06T00:00:00", "2019-08-07T00:00:00", "2019-08-08T00:00:00", "2019-08-09T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-16T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:00:00", "2019-08-26T00:00:00", "2019-08-27T00:00:00", "2019-08-28T00:00:00", "2019-08-29T00:00:00", "2019-08-30T00:00:00", "2019-09-02T00:00:00", "2019-09-03T00:00:00", "2019-09-04T00:00:00", "2019-09-05T00:00:00", "2019-09-06T00:00:00", "2019-09-09T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-16T00:00:00", "2019-09-17T00:00:00", "2019-09-18T00:00:00", "2019-09-19T00:00:00", "2019-09-20T00:00:00", "2019-09-23T00:00:00", "2019-09-24T00:00:00", "2019-09-25T00:00:00", "2019-09-26T00:00:00", "2019-09-27T00:00:00", "2019-09-30T00:00:00", "2019-10-01T00:00:00", "2019-10-02T00:00:00", "2019-10-04T00:00:00", "2019-10-07T00:00:00", "2019-10-08T00:00:00", "2019-10-10T00:00:00", "2019-10-11T00:00:00", "2019-10-14T00:00:00", "2019-10-15T00:00:00", "2019-10-16T00:00:00", "2019-10-17T00:00:00", "2019-10-18T00:00:00", "2019-10-21T00:00:00", "2019-10-22T00:00:00", "2019-10-23T00:00:00", "2019-10-24T00:00:00", "2019-10-25T00:00:00", "2019-10-28T00:00:00", "2019-10-29T00:00:00", "2019-10-30T00:00:00", "2019-10- ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333

# %%
import plotly.offline as offline
import plotly.graph_objs as go

trace = go.Scatter(x=df.날짜,
                   y=df.전일비,
                   name=item_name)

data=[trace]

layout = dict(title='{}의 종가(close) Time Series'.format(item_name))

fig = go.Figure(data=data, layout=layout)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="9460a964-5b17-4a4b-a7e4-0b49ad58d820" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9460a964-5b17-4a4b-a7e4-0b49ad58d820")) {
#                     Plotly.newPlot(
#                         '9460a964-5b17-4a4b-a7e4-0b49ad58d820',
#                         [{"name": "\uc2e0\ub77c\uc820", "type": "scatter", "x": ["2019-02-22T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23T00:00:00", "2019-05-24T00:00:00", "2019-05-27T00:00:00", "2019-05-28T00:00:00", "2019-05-29T00:00:00", "2019-05-30T00:00:00", "2019-05-31T00:00:00", "2019-06-03T00:00:00", "2019-06-04T00:00:00", "2019-06-05T00:00:00", "2019-06-07T00:00:00", "2019-06-10T00:00:00", "2019-06-11T00:00:00", "2019-06-12T00:00:00", "2019-06-13T00:00:00", "2019-06-14T00:00:00", "2019-06-17T00:00:00", "2019-06-18T00:00:00", "2019-06-19T00:00:00", "2019-06-20T00:00:00", "2019-06-21T00:00:00", "2019-06-24T00:00:00", "2019-06-25T00:00:00", "2019-06-26T00:00:00", "2019-06-27T00:00:00", "2019-06-28T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00", "2019-07-05T00:00:00", "2019-07-08T00:00:00", "2019-07-09T00:00:00", "2019-07-10T00:00:00", "2019-07-11T00:00:00", "2019-07-12T00:00:00", "2019-07-15T00:00:00", "2019-07-16T00:00:00", "2019-07-17T00:00:00", "2019-07-18T00:00:00", "2019-07-19T00:00:00", "2019-07-22T00:00:00", "2019-07-23T00:00:00", "2019-07-24T00:00:00", "2019-07-25T00:00:00", "2019-07-26T00:00:00", "2019-07-29T00:00:00", "2019-07-30T00:00:00", "2019-07-31T00:00:00", "2019-08-01T00:00:00", "2019-08-02T00:00:00", "2019-08-05T00:00:00", "2019-08-06T00:00:00", "2019-08-07T00:00:00", "2019-08-08T00:00:00", "2019-08-09T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-16T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:00:00", "2019-08-26T00:00:00", "2019-08-27T00:00:00", "2019-08-28T00:00:00", "2019-08-29T00:00:00", "2019-08-30T00:00:00", "2019-09-02T00:00:00", "2019-09-03T00:00:00", "2019-09-04T00:00:00", "2019-09-05T00:00:00", "2019-09-06T00:00:00", "2019-09-09T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-16T00:00:00", "2019-09-17T00:00:00", "2019-09-18T00:00:00", "2019-09-19T00:00:00", "2019-09-20T00:00:00", "2019-09-23T00:00:00", "2019-09-24T00:00:00", "2019-09-25T00:00:00", "2019-09-26T00:00:00", "2019-09-27T00:00:00", "2019-09-30T00:00:00", "2019-10-01T00:00:00", "2019-10-02T00:00:00", "2019-10-04T00:00:00", "2019-10-07T00:00:00", "2019-10-08T00:00:00", "2019-10-10T00:00:00", "2019-10-11T00:00:00", "2019-10-14T00:00:00", "2019-10-15T00:00:00", "2019-10-16T00:00:00", "2019-10-17T00:00:00", "2019-10-18T00:00:00", "2019-10-21T00:00:00", "2019-10-22T00:00:00", "2019-10-23T00:00:00", "2019-10-24T00:00:00", "2019-10-25T00:00:00", "2019-10-28T00:00:00", "2019-10-29T00:00:00", "2019-10-30T00:00:00", "2019-10- ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333

# %%
import plotly.offline as offline
import plotly.graph_objs as go

offline.init_notebook_mode(connected=True)

trace = go.Scatter(x=df.날짜,
                   y=df.전일비,
                   name=item_name)

data=[trace]

layout = dict( title='{}의 종가(close) Time Series'.format(item_name), xaxis=dict( rangeselector=dict( buttons=list([ dict(count=1, label='1m', step='month', stepmode='backward'), dict(count=3, label='3m', step='month', stepmode='backward'), dict(count=6, label='6m', step='month', stepmode='backward'), dict(step='all') ]) ), rangeslider=dict(), type='date' ) )

fig = go.Figure(data=data, layout=layout)
offline.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="f2a14c41-2597-4593-8a76-3007f5752d63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2a14c41-2597-4593-8a76-3007f5752d63")) {
#                     Plotly.newPlot(
#                         'f2a14c41-2597-4593-8a76-3007f5752d63',
#                         [{"name": "\uc2e0\ub77c\uc820", "type": "scatter", "x": ["2019-02-22T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23T00:00:00", "2019-05-24T00:00:00", "2019-05-27T00:00:00", "2019-05-28T00:00:00", "2019-05-29T00:00:00", "2019-05-30T00:00:00", "2019-05-31T00:00:00", "2019-06-03T00:00:00", "2019-06-04T00:00:00", "2019-06-05T00:00:00", "2019-06-07T00:00:00", "2019-06-10T00:00:00", "2019-06-11T00:00:00", "2019-06-12T00:00:00", "2019-06-13T00:00:00", "2019-06-14T00:00:00", "2019-06-17T00:00:00", "2019-06-18T00:00:00", "2019-06-19T00:00:00", "2019-06-20T00:00:00", "2019-06-21T00:00:00", "2019-06-24T00:00:00", "2019-06-25T00:00:00", "2019-06-26T00:00:00", "2019-06-27T00:00:00", "2019-06-28T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00", "2019-07-05T00:00:00", "2019-07-08T00:00:00", "2019-07-09T00:00:00", "2019-07-10T00:00:00", "2019-07-11T00:00:00", "2019-07-12T00:00:00", "2019-07-15T00:00:00", "2019-07-16T00:00:00", "2019-07-17T00:00:00", "2019-07-18T00:00:00", "2019-07-19T00:00:00", "2019-07-22T00:00:00", "2019-07-23T00:00:00", "2019-07-24T00:00:00", "2019-07-25T00:00:00", "2019-07-26T00:00:00", "2019-07-29T00:00:00", "2019-07-30T00:00:00", "2019-07-31T00:00:00", "2019-08-01T00:00:00", "2019-08-02T00:00:00", "2019-08-05T00:00:00", "2019-08-06T00:00:00", "2019-08-07T00:00:00", "2019-08-08T00:00:00", "2019-08-09T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-16T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:00:00", "2019-08-26T00:00:00", "2019-08-27T00:00:00", "2019-08-28T00:00:00", "2019-08-29T00:00:00", "2019-08-30T00:00:00", "2019-09-02T00:00:00", "2019-09-03T00:00:00", "2019-09-04T00:00:00", "2019-09-05T00:00:00", "2019-09-06T00:00:00", "2019-09-09T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-16T00:00:00", "2019-09-17T00:00:00", "2019-09-18T00:00:00", "2019-09-19T00:00:00", "2019-09-20T00:00:00", "2019-09-23T00:00:00", "2019-09-24T00:00:00", "2019-09-25T00:00:00", "2019-09-26T00:00:00", "2019-09-27T00:00:00", "2019-09-30T00:00:00", "2019-10-01T00:00:00", "2019-10-02T00:00:00", "2019-10-04T00:00:00", "2019-10-07T00:00:00", "2019-10-08T00:00:00", "2019-10-10T00:00:00", "2019-10-11T00:00:00", "2019-10-14T00:00:00", "2019-10-15T00:00:00", "2019-10-16T00:00:00", "2019-10-17T00:00:00", "2019-10-18T00:00:00", "2019-10-21T00:00:00", "2019-10-22T00:00:00", "2019-10-23T00:00:00", "2019-10-24T00:00:00", "2019-10-25T00:00:00", "2019-10-28T00:00:00", "2019-10-29T00:00:00", "2019-10-30T00:00:00", "2019-10- ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333

# %% [markdown]
# # 20191211 프로젝트

# %% [markdown]
# 먼저 기존에 있던 신라젠 데이터프레임 다시 추출해보기.

# %%
df.head()
# Out:
#             날짜     종가   전일비     시가     고가     저가      거래량
# 298 2019-02-22  72000  1400  72900  73500  71800   842080
# 297 2019-02-25  73300  1300  72100  73900  71500   799032
# 296 2019-02-26  72800   500  73600  74400  72800   659441
# 295 2019-02-27  73500   700  72700  73800  72300   555903
# 294 2019-02-28  74300   800  74200  76000  71300  2467512

# %% [markdown]
# 필요없는 전일비, 거래량 col은 지우기.

# %%
del df['전일비'], df['거래량'], df['날짜']
df.head()
# Out:
#         종가     시가     고가     저가
# 298  72000  72900  73500  71800
# 297  73300  72100  73900  71500
# 296  72800  73600  74400  72800
# 295  73500  72700  73800  72300
# 294  74300  74200  76000  71300

# %% [markdown]
# shift 사용해 전일 종가를 추출.

# %%
jongga_zonnal = df['종가'].shift(1, axis=0)
jongga_zonnal
# Out:
# 298        NaN
# 297    72000.0
# 296    73300.0
# 295    72800.0
# 294    73500.0
#         ...
# 5      13750.0
# 4      13200.0
# 3      13750.0
# 2      14050.0
# 1      14350.0
# Name: 종가, Length: 200, dtype: float64

# %%
df = pd.concat([df, jongga_zonnal], axis=1)
df.columns = ['종가', '시가', '고가', '저가', '전일종가']
df.head()
# Out:
#         종가     시가     고가     저가     전일종가
# 298  72000  72900  73500  71800      NaN
# 297  73300  72100  73900  71500  72000.0
# 296  72800  73600  74400  72800  73300.0
# 295  73500  72700  73800  72300  72800.0
# 294  74300  74200  76000  71300  73500.0

# %%
df_sub = df['종가'] - df['전일종가']
df_sub
# Out:
# 298       NaN
# 297    1300.0
# 296    -500.0
# 295     700.0
# 294     800.0
#         ...
# 5      -550.0
# 4       550.0
# 3       300.0
# 2       300.0
# 1      -500.0
# Length: 200, dtype: float64

# %%
df = pd.concat([df, df_sub], axis=1)
df
# Out:
#         종가     시가     고가     저가     전일종가       0
# 298  72000  72900  73500  71800      NaN     NaN
# 297  73300  72100  73900  71500  72000.0  1300.0
# 296  72800  73600  74400  72800  73300.0  -500.0
# 295  73500  72700  73800  72300  72800.0   700.0
# 294  74300  74200  76000  71300  73500.0   800.0
# ..     ...    ...    ...    ...      ...     ...
# 5    13200  13800  13850  13000  13750.0  -550.0
# 4    13750  13300  13950  13300  13200.0   550.0
# 3    14050  13850  14200  13500  13750.0   300.0
# 2    14350  14300  14500  14100  14050.0   300.0
# 1    13850  14250  14350  13800  14350.0  -500.0
#
# [200 rows x 6 columns]

# %%
df.rename(columns={0:"당일-전일"}, inplace = True)
df
# Out:
#         종가     시가     고가     저가     전일종가   당일-전일
# 298  72000  72900  73500  71800      NaN     NaN
# 297  73300  72100  73900  71500  72000.0  1300.0
# 296  72800  73600  74400  72800  73300.0  -500.0
# 295  73500  72700  73800  72300  72800.0   700.0
# 294  74300  74200  76000  71300  73500.0   800.0
# ..     ...    ...    ...    ...      ...     ...
# 5    13200  13800  13850  13000  13750.0  -550.0
# 4    13750  13300  13950  13300  13200.0   550.0
# 3    14050  13850  14200  13500  13750.0   300.0
# 2    14350  14300  14500  14100  14050.0   300.0
# 1    13850  14250  14350  13800  14350.0  -500.0
#
# [200 rows x 6 columns]

# %%
df_result = df['당일-전일'] / df['전일종가']

# %%
df = pd.concat([df, df_result], axis=1)
df
# Out:
#         종가     시가     고가     저가     전일종가   당일-전일         0
# 298  72000  72900  73500  71800      NaN     NaN       NaN
# 297  73300  72100  73900  71500  72000.0  1300.0  0.018056
# 296  72800  73600  74400  72800  73300.0  -500.0 -0.006821
# 295  73500  72700  73800  72300  72800.0   700.0  0.009615
# 294  74300  74200  76000  71300  73500.0   800.0  0.010884
# ..     ...    ...    ...    ...      ...     ...       ...
# 5    13200  13800  13850  13000  13750.0  -550.0 -0.040000
# 4    13750  13300  13950  13300  13200.0   550.0  0.041667
# 3    14050  13850  14200  13500  13750.0   300.0  0.021818
# 2    14350  14300  14500  14100  14050.0   300.0  0.021352
# 1    13850  14250  14350  13800  14350.0  -500.0 -0.034843
#
# [200 rows x 7 columns]

# %%
df.rename(columns={0:"등락률"}, inplace = True)

# %%
df
# Out:
#         종가     시가     고가     저가     전일종가   당일-전일       등락률
# 298  72000  72900  73500  71800      NaN     NaN       NaN
# 297  73300  72100  73900  71500  72000.0  1300.0  0.018056
# 296  72800  73600  74400  72800  73300.0  -500.0 -0.006821
# 295  73500  72700  73800  72300  72800.0   700.0  0.009615
# 294  74300  74200  76000  71300  73500.0   800.0  0.010884
# ..     ...    ...    ...    ...      ...     ...       ...
# 5    13200  13800  13850  13000  13750.0  -550.0 -0.040000
# 4    13750  13300  13950  13300  13200.0   550.0  0.041667
# 3    14050  13850  14200  13500  13750.0   300.0  0.021818
# 2    14350  14300  14500  14100  14050.0   300.0  0.021352
# 1    13850  14250  14350  13800  14350.0  -500.0 -0.034843
#
# [200 rows x 7 columns]

# %%
df_new = df['등락률'] * 100
df_new
# Out:
# 298         NaN
# 297    1.805556
# 296   -0.682128
# 295    0.961538
# 294    1.088435
#          ...
# 5     -4.000000
# 4      4.166667
# 3      2.181818
# 2      2.135231
# 1     -3.484321
# Name: 등락률, Length: 200, dtype: float64

# %%
df = pd.concat([df, df_new], axis=1)
df.columns.values[7] = '싀발럼'
df
# Out:
#         종가     시가     고가     저가     전일종가   당일-전일       등락률       싀발럼
# 298  72000  72900  73500  71800      NaN     NaN       NaN       NaN
# 297  73300  72100  73900  71500  72000.0  1300.0  0.018056  1.805556
# 296  72800  73600  74400  72800  73300.0  -500.0 -0.006821 -0.682128
# 295  73500  72700  73800  72300  72800.0   700.0  0.009615  0.961538
# 294  74300  74200  76000  71300  73500.0   800.0  0.010884  1.088435
# ..     ...    ...    ...    ...      ...     ...       ...       ...
# 5    13200  13800  13850  13000  13750.0  -550.0 -0.040000 -4.000000
# 4    13750  13300  13950  13300  13200.0   550.0  0.041667  4.166667
# 3    14050  13850  14200  13500  13750.0   300.0  0.021818  2.181818
# 2    14350  14300  14500  14100  14050.0   300.0  0.021352  2.135231
# 1    13850  14250  14350  13800  14350.0  -500.0 -0.034843 -3.484321
#
# [200 rows x 8 columns]

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color


s = df.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow0_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow1_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col5 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col6 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow2_col7 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow3_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow4_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow5_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow6_col7 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col5 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col6 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow7_col7 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col5 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col6 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow8_col7 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col5 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col6 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow9_col7 {
#             color:  red;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col0 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col1 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col2 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col3 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col4 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col5 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col6 {
#             color:  black;
#         }    #T_d0f79c02_1c0e_11ea_93b3_d4619d16637crow10_col7 {
#             color:
